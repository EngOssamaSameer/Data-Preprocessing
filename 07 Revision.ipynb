# %% [markdown]
# # Revision

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# #### 1)Understand the Data

# %%
dataset = pd.read_csv('Dataset salary re.csv')

# %%
dataset.head()
# Out:
#    work_year experience_level employment_type      job_title    salary  \
# 0     2024.0               SE              FT    AI Engineer  202730.0
# 1     2024.0               SE              FT    AI Engineer  202730.0
# 2     2024.0               SE              FT    AI Engineer  202730.0
# 3     2024.0               SE              FT    AI Engineer  202730.0
# 4     2024.0               SE              FT  Data Engineer  130500.0
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         202730                 US           0.0
# 1             USD         202730                 US           0.0
# 2             USD         202730                 US           0.0
# 3             USD         202730                 US           0.0
# 4             USD         130500                 US           0.0
#
#   company_location company_size  Unnamed: 11
# 0               US            M          7.0
# 1               US            M          7.0
# 2               US            M          7.0
# 3               US            M          7.0
# 4               US            M          7.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16536 entries, 0 to 16535
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  float64
#  1   experience_level    16535 non-null  object
#  2   employment_type     16535 non-null  object
#  3   job_title           16536 non-null  object
#  4   salary              16533 non-null  float64
#  5   salary_currency     16536 non-null  object
#  6   salary_in_usd       16536 non-null  int64
#  7   employee_residence  16536 non-null  object
#  8   remote_ratio        16536 non-null  float64
#  9   company_location    16535 non-null  object
#  10  company_size        16536 non-null  object
#  11  Unnamed: 11         1971 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# #### 2)Remove Unnecessary Data

# %%
# Remove duplicate rows
dataset.drop_duplicates(inplace=True)

# %%
dataset.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0     2024.0               SE              FT                AI Engineer
# 4     2024.0               SE              FT              Data Engineer
# 5     2024.0               SE              FT              Data Engineer
# 6     2024.0               SE              FT  Machine Learning Engineer
# 7     2024.0               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730.0             USD         202730                 US           0.0
# 4  130500.0             USD         130500                 US           0.0
# 5   96000.0             USD          96000                 US           0.0
# 6  190000.0             USD         190000                 US           0.0
# 7  160000.0             USD         160000                 US           0.0
#
#   company_location company_size  Unnamed: 11
# 0               US            M          7.0
# 4               US            M          7.0
# 5               US            M          7.0
# 6               US            M          7.0
# 7               US            M          7.0

# %%
# Calculate the percentage of null values in each column
null_percentage = dataset.isnull().mean() * 100

# Display the result
print(null_percentage)
# Out:
# work_year              0.018882
# experience_level       0.009441
# employment_type        0.009441
# job_title              0.000000
# salary                 0.028323
# salary_currency        0.000000
# salary_in_usd          0.000000
# employee_residence     0.000000
# remote_ratio           0.000000
# company_location       0.009441
# company_size           0.000000
# Unnamed: 11           84.658233
# dtype: float64

# %%
dataset = dataset.drop('Unnamed: 11', axis=1)

# %%
dataset.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0     2024.0               SE              FT                AI Engineer
# 4     2024.0               SE              FT              Data Engineer
# 5     2024.0               SE              FT              Data Engineer
# 6     2024.0               SE              FT  Machine Learning Engineer
# 7     2024.0               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730.0             USD         202730                 US           0.0
# 4  130500.0             USD         130500                 US           0.0
# 5   96000.0             USD          96000                 US           0.0
# 6  190000.0             USD         190000                 US           0.0
# 7  160000.0             USD         160000                 US           0.0
#
#   company_location company_size
# 0               US            M
# 4               US            M
# 5               US            M
# 6               US            M
# 7               US            M

# %% [markdown]
# #### 3)Handle Missing Values

# %%
# Check for missing values
dataset.isnull().sum()
# Out:
# work_year             2
# experience_level      1
# employment_type       1
# job_title             0
# salary                3
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      1
# company_size          0
# dtype: int64

# %%
# Mean imputation for numerical columns
for column in dataset.columns:
    if dataset[column].dtype in ['int64', 'float64']:
        dataset[column].fillna(dataset[column].mean(), inplace=True)

# %%
# mode imputation for numerical columns
for column in dataset.columns:
    if dataset[column].dtype in ['object']:
        dataset[column].fillna(dataset[column].mode()[0], inplace=True)

# %%
# Check for missing values
dataset.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# #### 4)Outlier Detection and Treatment

# %%
# Identify numerical columns
numerical_columns = dataset.select_dtypes(include=[np.number]).columns
print(f"Numerical columns: {numerical_columns}")
# Out:
# Numerical columns: Index(['work_year', 'salary', 'salary_in_usd', 'remote_ratio'], dtype='object')

# %%
# Calculate quartiles and IQR for each column
Q1 = dataset[numerical_columns].quantile(0.25)
Q3 = dataset[numerical_columns].quantile(0.75)
IQR = Q3 - Q1

# %%
# Define the boundaries to identify outliers for each column
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Handling outliers using NumPy for each column
for col in dataset[numerical_columns]:
    dataset[col] = np.where(dataset[col] < lower_bound[col], lower_bound[col], np.where(dataset[col] > upper_bound[col], upper_bound[col], dataset[col]))

# %% [markdown]
# #### 5)Encoding Categorical Variables

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# %%
# Loop through each column in the DataFrame
for column in dataset.columns:
    if dataset[column].dtype == 'object':  
        dataset[column] = label_encoder.fit_transform(dataset[column])

# %%
dataset.head()
# Out:
#    work_year  experience_level  employment_type  job_title    salary  \
# 0     2024.0                 3                2          3  202730.0
# 4     2024.0                 3                2         58  130500.0
# 5     2024.0                 3                2         58   96000.0
# 6     2024.0                 3                2        121  190000.0
# 7     2024.0                 3                2        121  160000.0
#
#    salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0               21       202730.0                  84           0.0
# 4               21       130500.0                  84           0.0
# 5               21        96000.0                  84           0.0
# 6               21       190000.0                  84           0.0
# 7               21       160000.0                  84           0.0
#
#    company_location  company_size
# 0                74             1
# 4                74             1
# 5                74             1
# 6                74             1
# 7                74             1

# %% [markdown]
# #### 6)Standardize or Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize the MinMaxScaler
min_max_scaler = MinMaxScaler()

# %%
# Fit and transform the numerical columns
dataset = min_max_scaler.fit_transform(dataset)

# %%
dataset = pd.DataFrame(dataset)

# %%
dataset.head()
# Out:
#     0    1         2         3         4         5         6         7    8   \
# 0  1.0  1.0  0.666667  0.019355  0.606104  0.954545  0.614501  0.965517  0.0
# 1  1.0  1.0  0.666667  0.374194  0.374139  0.954545  0.378069  0.965517  0.0
# 2  1.0  1.0  0.666667  0.374194  0.263342  0.954545  0.265139  0.965517  0.0
# 3  1.0  1.0  0.666667  0.780645  0.565222  0.954545  0.572831  0.965517  0.0
# 4  1.0  1.0  0.666667  0.780645  0.468877  0.954545  0.474632  0.965517  0.0
#
#          9    10
# 0  0.973684  0.5
# 1  0.973684  0.5
# 2  0.973684  0.5
# 3  0.973684  0.5
# 4  0.973684  0.5
