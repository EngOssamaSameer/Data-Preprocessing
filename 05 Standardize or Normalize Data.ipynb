# %% [markdown]
# # Standardize or Normalize Data

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = pd.read_csv('Dataset salary 2024.csv')

# %%
dataset.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %%
# Identify numerical columns
numerical_columns = dataset.select_dtypes(include=[np.number]).columns

# %% [markdown]
# # Standardize Data (Z-score normalization)

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# %%
# Fit and transform the numerical columns
df_standardized = dataset.copy()
df_standardized[numerical_columns] = scaler.fit_transform(dataset[numerical_columns])

# %% [markdown]
# ### fit method

# %% [raw]
# The fit method does not alter the data; it only learns from it

# %% [markdown]
# ### Transform

# %% [raw]
# This method changes the data based on the learned parameters.

# %%
print("\nStandardized dataset:")
df_standardized.head()
# Out:
# Standardized dataset:
#    work_year experience_level employment_type                  job_title  \
# 0   1.083524               SE              FT                AI Engineer
# 1   1.083524               SE              FT                AI Engineer
# 2   1.083524               SE              FT              Data Engineer
# 3   1.083524               SE              FT              Data Engineer
# 4   1.083524               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  0.114649             USD       0.774317                 US     -0.692066
# 1 -0.210494             USD      -0.840381                 US     -0.692066
# 2 -0.097670             USD      -0.280086                 US     -0.692066
# 3 -0.199083             USD      -0.783712                 US     -0.692066
# 4  0.077229             USD       0.588487                 US     -0.692066
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %% [markdown]
# # Normalize Data (Min-Max scaling)

# %%
# Initialize the MinMaxScaler
min_max_scaler = MinMaxScaler()

# %%
# Fit and transform the numerical columns
df_normalized = dataset.copy()
df_normalized[numerical_columns] = min_max_scaler.fit_transform(dataset[numerical_columns])

# %%
print("\nNormalized dataset:")
df_normalized.head()
# Out:
# Normalized dataset:
#    work_year experience_level employment_type                  job_title  \
# 0        1.0               SE              FT                AI Engineer
# 1        1.0               SE              FT                AI Engineer
# 2        1.0               SE              FT              Data Engineer
# 3        1.0               SE              FT              Data Engineer
# 4        1.0               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  0.006211             USD       0.239146                 US           0.0
# 1  0.002571             USD       0.098239                 US           0.0
# 2  0.003834             USD       0.147134                 US           0.0
# 3  0.002699             USD       0.103185                 US           0.0
# 4  0.005792             USD       0.222930                 US           0.0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %% [markdown]
# # Z-Score
# Centers the data around 0 with a standard deviation of 1.
#
# # Min-Max
# Scales the data within a specified range, usually [0, 1].
