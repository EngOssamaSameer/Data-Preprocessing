# %% [markdown]
# # Data-Preprocessing
# ## Remove Unnecessary Data

# %%
import pandas as pd

# %%
#load dataset
df = pd.read_csv('Dataset.csv')

# %%
#show few rows
df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     1     1             2  $780,000,000                     $780,000,000
# 2     1     1             2  $780,000,000                     $780,000,000
# 3     2     1          7[2]  $579,800,000                     $579,800,000
# 4     3  1[4]          2[5]  $411,000,000                     $560,622,615
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 2  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 3       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 4       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
#
#   Ref.
# 0  [1]
# 1  [1]
# 2  [1]
# 3  [3]
# 4  [6]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              22 non-null     int64
#  1   Peak                              11 non-null     object
#  2   All Time Peak                     8 non-null      object
#  3   Actual gross                      22 non-null     object
#  4   Adjusted gross (in 2022 dollars)  22 non-null     object
#  5   Artist                            22 non-null     object
#  6   Tour title                        22 non-null     object
#  7   Year(s)                           22 non-null     object
#  8   Shows                             22 non-null     int64
#  9   Average gross                     22 non-null     object
#  10  Ref.                              22 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 2.0+ KB

# %%
df.drop_duplicates()
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 3      2      1          7[2]     $579,800,000
# 4      3   1[4]          2[5]     $411,000,000
# 5      4   2[7]         10[7]     $397,300,000
# 6      5   2[4]           NaN     $345,675,146
# 7      6   2[4]         10[9]     $305,158,363
# 8      7  2[10]           NaN     $280,000,000
# 9      7    NaN           NaN     $257,600,000
# 10     9    NaN           NaN     $256,084,556
# 11    10    NaN           NaN     $250,400,000
# 12    11    NaN           NaN  $229,100,000[b]
# 13    12    NaN        14[17]     $227,400,000
# 14    13    NaN           NaN     $204,000,000
# 15    14  1[20]           NaN     $200,000,000
# 16    15   2[c]           NaN     $194,000,000
# 17    16    NaN           NaN     $184,000,000
# 18    17    NaN           NaN     $170,000,000
# 19    18    NaN           NaN     $169,800,000
# 20    19    NaN           NaN  $167,700,000[e]
# 21    20    NaN           NaN     $150,000,000
#
#    Adjusted gross (in 2022 dollars)        Artist  \
# 0                      $780,000,000  Taylor Swift
# 3                      $579,800,000       Beyoncé
# 4                      $560,622,615       Madonna
# 5                      $454,751,555          Pink
# 6                      $402,844,849  Taylor Swift
# 7                      $388,978,496       Madonna
# 8                      $381,932,682   Celine Dion
# 9                      $257,600,000          Pink
# 10                     $312,258,401       Beyoncé
# 11                     $309,141,878  Taylor Swift
# 12                     $283,202,896       Beyoncé
# 13                     $295,301,479     Lady Gaga
# 14                     $251,856,802    Katy Perry
# 15                     $299,676,265          Cher
# 16                     $281,617,035       Madonna
# 17                     $227,452,347          Pink
# 18                     $213,568,571     Lady Gaga
# 19                     $207,046,755       Madonna
# 20                     $204,486,106         Adele
# 21                     $185,423,109  Taylor Swift
#
#                                   Tour title    Year(s)  Shows Average gross  \
# 0                            The Eras Tour †  2023–2024     56   $13,928,571
# 3                     Renaissance World Tour       2023     56   $10,353,571
# 4                Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 5                Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 6                    Reputation Stadium Tour       2018     53    $6,522,173
# 7                              The MDNA Tour       2012     88    $3,467,709
# 8                  Taking Chances World Tour  2008–2009    131    $2,137,405
# 9                          Summer Carnival †  2023–2024     41    $6,282,927
# 10                  The Formation World Tour       2016     49    $5,226,215
# 11                       The 1989 World Tour       2015     85    $2,945,882
# 12           The Mrs. Carter Show World Tour  2013–2014    132    $1,735,606
# 13                   The Monster Ball Tour *  2009–2011    203    $1,118,227
# 14                      Prismatic World Tour  2014–2015    151    $1,350,993
# 15  Living Proof: The Farewell Tour ‡[21][a]  2002–2005    325      $615,385
# 16                          Confessions Tour       2006     60    $3,233,333
# 17                 The Truth About Love Tour  2013–2014    142    $1,295,775
# 18                        Born This Way Ball  2012–2013     98    $1,734,694
# 19                          Rebel Heart Tour  2015–2016     82    $2,070,732
# 20                           Adele Live 2016  2016–2017    121    $1,385,950
# 21                              The Red Tour  2013–2014     86    $1,744,186
#
#         Ref.
# 0        [1]
# 3        [3]
# 4        [6]
# 5        [7]
# 6        [8]
# 7        [9]
# 8       [11]
# 9       [12]
# 10      [13]
# 11      [14]
# 12  [15][16]
# 13      [18]
# 14      [19]
# 15      [20]
# 16       [5]
# 17      [22]
# 18       [d]
# 19       [4]
# 20      [25]
# 21      [26]

# %%
#calculate the percentage of null values in each column
null_prec = df.isnull().mean() * 100
print(null_prec)
# Out:
# Rank                                 0.000000
# Peak                                50.000000
# All Time Peak                       63.636364
# Actual gross                         0.000000
# Adjusted gross (in 2022 dollars)     0.000000
# Artist                               0.000000
# Tour title                           0.000000
# Year(s)                              0.000000
# Shows                                0.000000
# Average gross                        0.000000
# Ref.                                 0.000000
# dtype: float64

# %%
#list of columns to drop 
column_to_drop = ['Peak', 'All Time Peak']
# Drop the columns
df.drop(columns = column_to_drop)
# Out:
#     Rank     Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      1     $780,000,000                     $780,000,000  Taylor Swift
# 1      1     $780,000,000                     $780,000,000  Taylor Swift
# 2      1     $780,000,000                     $780,000,000  Taylor Swift
# 3      2     $579,800,000                     $579,800,000       Beyoncé
# 4      3     $411,000,000                     $560,622,615       Madonna
# 5      4     $397,300,000                     $454,751,555          Pink
# 6      5     $345,675,146                     $402,844,849  Taylor Swift
# 7      6     $305,158,363                     $388,978,496       Madonna
# 8      7     $280,000,000                     $381,932,682   Celine Dion
# 9      7     $257,600,000                     $257,600,000          Pink
# 10     9     $256,084,556                     $312,258,401       Beyoncé
# 11    10     $250,400,000                     $309,141,878  Taylor Swift
# 12    11  $229,100,000[b]                     $283,202,896       Beyoncé
# 13    12     $227,400,000                     $295,301,479     Lady Gaga
# 14    13     $204,000,000                     $251,856,802    Katy Perry
# 15    14     $200,000,000                     $299,676,265          Cher
# 16    15     $194,000,000                     $281,617,035       Madonna
# 17    16     $184,000,000                     $227,452,347          Pink
# 18    17     $170,000,000                     $213,568,571     Lady Gaga
# 19    18     $169,800,000                     $207,046,755       Madonna
# 20    19  $167,700,000[e]                     $204,486,106         Adele
# 21    20     $150,000,000                     $185,423,109  Taylor Swift
#
#                                   Tour title    Year(s)  Shows Average gross  \
# 0                            The Eras Tour †  2023–2024     56   $13,928,571
# 1                            The Eras Tour †  2023–2024     56   $13,928,571
# 2                            The Eras Tour †  2023–2024     56   $13,928,571
# 3                     Renaissance World Tour       2023     56   $10,353,571
# 4                Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 5                Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 6                    Reputation Stadium Tour       2018     53    $6,522,173
# 7                              The MDNA Tour       2012     88    $3,467,709
# 8                  Taking Chances World Tour  2008–2009    131    $2,137,405
# 9                          Summer Carnival †  2023–2024     41    $6,282,927
# 10                  The Formation World Tour       2016     49    $5,226,215
# 11                       The 1989 World Tour       2015     85    $2,945,882
# 12           The Mrs. Carter Show World Tour  2013–2014    132    $1,735,606
# 13                   The Monster Ball Tour *  2009–2011    203    $1,118,227
# 14                      Prismatic World Tour  2014–2015    151    $1,350,993
# 15  Living Proof: The Farewell Tour ‡[21][a]  2002–2005    325      $615,385
# 16                          Confessions Tour       2006     60    $3,233,333
# 17                 The Truth About Love Tour  2013–2014    142    $1,295,775
# 18                        Born This Way Ball  2012–2013     98    $1,734,694
# 19                          Rebel Heart Tour  2015–2016     82    $2,070,732
# 20                           Adele Live 2016  2016–2017    121    $1,385,950
# 21                              The Red Tour  2013–2014     86    $1,744,186
#
#         Ref.
# 0        [1]
# 1        [1]
# 2        [1]
# 3        [3]
# 4        [6]
# 5        [7]
# 6        [8]
# 7        [9]
# 8       [11]
# 9       [12]
# 10      [13]
# 11      [14]
# 12  [15][16]
# 13      [18]
# 14      [19]
# 15      [20]
# 16       [5]
# 17      [22]
# 18       [d]
# 19       [4]
# 20      [25]
# 21      [26]
